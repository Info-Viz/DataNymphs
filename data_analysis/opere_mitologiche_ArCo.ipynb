# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
#carichiamo il csv pulito con i soggetti di Wikidata
df_wikidata = pd.read_csv("wd_dataset_pulito.csv", encoding="utf-8")

df_wikidata.head(3)
# Out:
#                                     entity      label aliases  \
# 0   http://www.wikidata.org/entity/Q279782  Abarbarea     NaN
# 1  http://www.wikidata.org/entity/Q2370052     Acanto     NaN
# 2  http://www.wikidata.org/entity/Q4668463     Acaste     NaN
#
#                                          description     category
# 0                       naiade della mitologia greca  greek_deity
# 1  personaggio della mitologia greca, probabilmen...  greek_deity
# 2                     Oceanina nella mitologia greca  greek_deity

# %% [markdown]
# <p>
# After creating the Wikidata mythology dataset, the next step focused on preparing a reference vocabulary that could be used to identify mythology-related subjects within the ArCo dataset.
# </p>
#
# <p>
# The filtering process was based on the <b>labels and aliases</b> extracted from Wikidata entities.
# These terms constituted the vocabulary used to match mythological subjects appearing in ArCo metadata.
# </p>

# %%
#estraggo tutte le label di wikidata 
labels = (
    df_wikidata["label"]
    .dropna() #tolgo i valori nulli
    .str.strip() #tolgo gli spazi bianchi all'inizio e alla fine
    .tolist() #converto in lista

)

#estraggo gli aliases di wikidata separando quelli multipli
aliases = []
for alias_str in df_wikidata["aliases"].dropna(): #per ogni stringa di alias che non è nulla
    alias_list = [alias.strip() for alias in alias_str.split(",")] #separo gli alias con la virgola, tolgo gli spazi e metto tutto in minuscolo
    aliases.extend(alias_list) #aggiungo alla lista totale degli alias

#unisco tutto togliendo i duplicati
myth_terms = list(set(labels + aliases)) 
len(myth_terms)
# Out:
# 2928

# %% [markdown]
# The next step focused on accessing the ArCo knowledge graph in order to identify cultural heritage items related to mythology.
#
# The ArCo SPARQL endpoint was accessed through the SPARQLWrapper Python library, allowing direct querying of the knowledge graph.

# %%
#ENDPOINT SPARLQ DI ARCO 
arco_endpoint = "https://dati.cultura.gov.it/sparql"

sparql_arco = SPARQLWrapper(arco_endpoint)
sparql_arco.setReturnFormat(JSON)

# %% [markdown]
# Before applying mythology-related filters, an initial exploratory query was performed to determine the <b>total number of historical and artistic cultural heritage objects</b> available in ArCo.
#
# The query targeted entities classified as HistoricOrArtisticProperty, which represent historical and artistic cultural heritage assets within the ArCo ontology.

# %%
# NUMERO TOTALE DEI BENI STORICO ARTISTICI 
query1 = """
PREFIX arco: <https://w3id.org/arco/ontology/arco/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 

SELECT (COUNT(DISTINCT ?item) AS ?totalItems)
WHERE {
  # ?item rdf:type <https://w3id.org/arco/ontology/arco/HistoricOrArtisticProperty> .
}
"""


sparql_arco.setQuery(query1)
results = sparql_arco.query().convert()

for result in results["results"]["bindings"]:
    print(f"Total Historic or Artistic Properties: {result['totalItems']['value']}")
# Out:
# Total Historic or Artistic Properties: 2259266

# %% [markdown]
# For each cultural heritage item, the extraction process retrieved:
#
# - the unique item URI,
# - the item label,
# - and the associated subject information.
#
# The subject field was particularly important because it represents the semantic description of the cultural object and constitutes the main element used to identify mythology-related items.

# %% [markdown]
# Due to the large size of the ArCo knowledge graph, the extraction process was performed incrementally using <b>batch queries </b>.
#
# Instead of retrieving the entire dataset in a single request, the workflow divided the extraction into smaller portions of data using LIMIT and OFFSET parameters within the SPARQL query.
#
# Each iteration retrieved a subset of cultural heritage items and progressively appended the results to a cumulative list.

# %%
rows = []
batch_size = 20000
total_items = 2258640   #numero totale quando abbiamo creato il codice il mese scorso

for offset in range(0, total_items, batch_size):
    print(f"Processando batch: offset={offset}, items processati={len(rows)}")
    
    query2 = f"""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX a-cd: <https://w3id.org/arco/ontology/context-description/>

SELECT ?item ?subject ?label
WHERE {{

  # ?item rdf:type <https://w3id.org/arco/ontology/arco/HistoricOrArtisticProperty> .
  
  OPTIONAL {{ ?item rdfs:label ?label . }}

  OPTIONAL {{ ?item a-cd:subject ?subject . }}

}}
LIMIT {batch_size}
OFFSET {offset}
"""
    
    sparql_arco.setQuery(query2)
    results = sparql_arco.query().convert()
    
    # estrai i dati da questo batch
    for r in results["results"]["bindings"]:
        rows.append({
            "item": r["item"]["value"] if "item" in r else None,
            "label": r["label"]["value"] if "label" in r else None,
            "subject": r["subject"]["value"] if "subject" in r else None
        })
    
    # se il batch è vuoto, ferma il loop
    if len(results["results"]["bindings"]) < batch_size:
        print(f"Batch incompleto ({len(results['results']['bindings'])} items), fine loop")
        break
# Out:
# Processando batch: offset=0, items processati=0
# Processando batch: offset=20000, items processati=20000
# Processando batch: offset=40000, items processati=40000
# Processando batch: offset=60000, items processati=60000
# Processando batch: offset=80000, items processati=80000
# Processando batch: offset=100000, items processati=100000
# Processando batch: offset=120000, items processati=120000
# Processando batch: offset=140000, items processati=140000
# Processando batch: offset=160000, items processati=160000
# Processando batch: offset=180000, items processati=180000
# Processando batch: offset=200000, items processati=200000
# Processando batch: offset=220000, items processati=220000
# Processando batch: offset=240000, items processati=240000
# Processando batch: offset=260000, items processati=260000
# Processando batch: offset=280000, items processati=280000
# Processando batch: offset=300000, items processati=300000
# Processando batch: offset=320000, items processati=320000
# Processando batch: offset=340000, items processati=340000
# Processando batch: offset=360000, items processati=360000
# Processando batch: offset=380000, items processati=380000
# Processando batch: offset=400000, items processati=400000
# Processando batch: offset=420000, items processati=420000
# Processando batch: offset=440000, items processati=440000
# Processando batch: offset=460000, items processati=460000
# Processando batch: offset=480000, items processati=480000
# Processando batch: offset=500000, items processati=500000
# Processando batch: offset=520000, items processati=520000
# Processando batch: offset=540000, items processati=540000
# Processando batch: offset=560000, items processati=560000
# Processando batch: offset=580000, items processati=580000
# Processando batch: offset=600000, items processati=600000
# Processando batch: offset=620000, items processati=620000
# Processando batch: offset=640000, items processati=640000
# Processando batch: offset=660000, items processati=660000
# Processando batch: offset=680000, items processati=680000
# Processando batch: offset=700000, items processati=700000
# Processando batch: offset=720000, items processati=720000
# Processando batch: offset=740000, items processati=740000
# Processando batch: offset=760000, items processati=760000
# Processando batch: offset=780000, items processati=780000
# Processando batch: offset=800000, items processati=800000
# Processando batch: offset=820000, items processati=820000
# Processando batch: offset=840000, items processati=840000
# Processando batch: offset=860000, items processati=860000
# Processando batch: offset=880000, items processati=880000
# Processando batch: offset=900000, items processati=900000
# Processando batch: offset=920000, items processati=920000
# Processando batch: offset=940000, items processati=940000
# Processando batch: offset=960000, items processati=960000
# Processando batch: offset=980000, items processati=980000
# Processando batch: offset=1000000, items processati=1000000
# Processando batch: offset=1020000, items processati=1020000
# Processando batch: offset=1040000, items processati=1040000
# Processando batch: offset=1060000, items processati=1060000
# Processando batch: offset=1080000, items processati=1080000
# Processando batch: offset=1100000, items processati=1100000
# Processando batch: offset=1120000, items processati=1120000
# Processando batch: offset=1140000, items processati=1140000
# Processando batch: offset=1160000, items processati=1160000
# Processando batch: offset=1180000, items processati=1180000
# Processando batch: offset=1200000, items processati=1200000
# Processando batch: offset=1220000, items processati=1220000
# Processando batch: offset=1240000, items processati=1240000
# Processando batch: offset=1260000, items processati=1260000
# Processando batch: offset=1280000, items processati=1280000
# Processando batch: offset=1300000, items processati=1300000
# Processando batch: offset=1320000, items processati=1320000
# Processando batch: offset=1340000, items processati=1340000
# Processando batch: offset=1360000, items processati=1360000
# Processando batch: offset=1380000, items processati=1380000
# Processando batch: offset=1400000, items processati=1400000
# Processando batch: offset=1420000, items processati=1420000
# Processando batch: offset=1440000, items processati=1440000
# Processando batch: offset=1460000, items processati=1460000
# Processando batch: offset=1480000, items processati=1480000
# Processando batch: offset=1500000, items processati=1500000
# Processando batch: offset=1520000, items processati=1520000
# Processando batch: offset=1540000, items processati=1540000
# Processando batch: offset=1560000, items processati=1560000
# Processando batch: offset=1580000, items processati=1580000
# Processando batch: offset=1600000, items processati=1600000
# Processando batch: offset=1620000, items processati=1620000
# Processando batch: offset=1640000, items processati=1640000
# Processando batch: offset=1660000, items processati=1660000
# Processando batch: offset=1680000, items processati=1680000
# Processando batch: offset=1700000, items processati=1700000
# Processando batch: offset=1720000, items processati=1720000
# Processando batch: offset=1740000, items processati=1740000
# Processando batch: offset=1760000, items processati=1760000
# Processando batch: offset=1780000, items processati=1780000
# Processando batch: offset=1800000, items processati=1800000
# Processando batch: offset=1820000, items processati=1820000
# Processando batch: offset=1840000, items processati=1840000
# Processando batch: offset=1860000, items processati=1860000
# Processando batch: offset=1880000, items processati=1880000
# Processando batch: offset=1900000, items processati=1900000
# Processando batch: offset=1920000, items processati=1920000
# Processando batch: offset=1940000, items processati=1940000
# Processando batch: offset=1960000, items processati=1960000
# Processando batch: offset=1980000, items processati=1980000
# Processando batch: offset=2000000, items processati=2000000
# Processando batch: offset=2020000, items processati=2020000
# Processando batch: offset=2040000, items processati=2040000
# Processando batch: offset=2060000, items processati=2060000
# Processando batch: offset=2080000, items processati=2080000
# Processando batch: offset=2100000, items processati=2100000
# Processando batch: offset=2120000, items processati=2120000
# Processando batch: offset=2140000, items processati=2140000
# Processando batch: offset=2160000, items processati=2160000
# Processando batch: offset=2180000, items processati=2180000
# Processando batch: offset=2200000, items processati=2200000
# Processando batch: offset=2220000, items processati=2220000
# Processando batch: offset=2240000, items processati=2240000

# %% [markdown]
# After completing all extraction batches, the retrieved data was consolidated into a single DataFrame.

# %%
# creiamo il dataframe consolidato
df_arco = pd.DataFrame(rows)
df_arco = df_arco.drop_duplicates(subset="item")

print(f"Righe totali in df_arco : {len(df_arco)}")
df_arco[["item", "label", "subject"]].head(1)
# Out:
# Righe totali in df_arco : 1120196
#                                                 item  \
# 0  https://w3id.org/arco/resource/HistoricOrArtis...
#
#                                                label  \
# 0  Arlecchino primordiale. Fine del cinquecento. ...
#
#                                    subject
# 0  figurino per costume di scena, maschile

# %%
#ESTRAIAMO SOLO I SOGGETTI MITOLOGICI 

import re

# 1. filtro base --> togliamo i NaN
df_arco = df_arco[df_arco["subject"].notna()].copy()

#creiamo la nostra lista di termini myth_terms
terms = [
    re.escape(t)
    for t in myth_terms
    if isinstance(t, str)
    and t.strip() != ""
    and t[0].isupper()  
]

# regex unica case-sensitive e per evitare termini composti
pattern = r'(?<![A-Za-zÀ-ÿ])(' + '|'.join(terms) + r')(?![A-Za-zÀ-ÿ])'
regex = re.compile(pattern)


#TERMINI DA ACCETTARE SOLO SE COMPAIONO INSIEME A QUESTE PAROLE []
context_rules = {
    "Ascanio" : ["fuoco", "cervo"],"Callisto": ["Arcade", "Diana"],"Concordia": ["Allegoria", "Innocenza", "Giustizia"],
    "Cornacchia": ["metamorfosi"],"Egeo": ["Teseo"],"Elena": ["ratto"],"Ettore": ["morte", "Protesilao", "Achille", "Andromaca", "Paride"],
    "Europa": ["ratto", "Toro", "sibilla", "mito","allegoria","ancelle","leone"],
    "Grazie" : ["tre", "danzanti"],"Ida" : ["Linceo"],"Ippolito":["episodi", "caduta", "morte"],
    "Nilo":["personificazione","allegoria"],"Roma":["dea"],"Silvano":["Dio"],"Sonno":["allegoria"],
    "Vesta":["Giove"],"Vittoria":["allegoria"]
}


# TERMINI DA ESCLUDERE SE COMPAIONO CON DETERMINATE PAROLE
exclusion_rules = {
    "Abbondanza": ["Santa", "Sant","san","papa"],"Amore": ["Dio", "Madonna", "castello", "fontana","antica"],"Andromeda":["galassia"],"Apollo":["sala","tempio"],
    "Atlante":["Scienze","turisti"],"Carità": ["Santa", "Sant", "Maria"],
    "Carita": ["Santa", "Sant", "Maria"],"Diana" : ["Beata", "duca","scenografia","tempio","conte","san"],
    "Dioniso": ["stemma","stemmi", "san", "santi", "s."],"Dionisio":["Ritratto","san","barletta","beati","vescovo","Santi","stemma","papa","padre","beato"],
    "Elio" : ["ponte","ritratto","paesaggio", "veduta"],"Enea": ["Beato", "discepolo","stemma", "papa", "silvio"],
    "Ercole": ["Ricotti", "Dandini", "Comini", "Farnese","cardinale", "tempio", "stemma", "ritratto", "Roccotti", "colonne", "porto", "basilica", "santa"],
    "Ermes" : ["ritratto"],"Esculapio": ["tempio"],
    "Fede" : ["santi", "sant", "san", "dottrina", "biblici", "Francia", "cattolica", "madonna", "evangelisti", "religione", "dio", "angeli", "angioletti","santa", "papa", "santo", "cristiana", "chiesa", "miracolo", "misericordia","virtù", "ritratto", "stemma"],
    "Flora" :["ritratto", "sante", "circo", "ruota", "iside", "madonna", "tempio"],"Galatea":["ritratto"],
    "Giasone":["san","ritratto"],"Giove":["san","tempio"],
    "Giunone":["scenografia", "tempio"],"Giustizia" : ["porta", "palazzo", "misericordia", "san", "santa", "papa", "imperatore", "papale","Virtù", "apostoli","papa","Giglio"],
    "Gorgone" : ["santa"],"greco":["testo","teatro"],"Io": ["ritratti "],"Ippolito":["Nievo"],"Lavinia":["ritratto", "autoritratto"],
    "Leandro" : ["autoritratto","ritratto","stemma","San", "busto", "torre"],"Marte":["tempio","sala","ultore"],
    "Medea":["Colleoni"],"Mercurio":["tempio","san","assiso"],"Mirra":["San"],"Minerva":["autoritratto","chiesa","tempio"],
    "Narciso":["san"],"Nereo":["ritratto","san","santi","SS."],"Nettuno":["veduta"],"Oceano":["Atlantico"],
    "Oreste":["Ritratto","autoritratto"],"Pan":["zucchero","veduta"],"Patroclo":["san"],"Pirro":["Stipiciano"],"Pluto":["Topolino","Disney"],
    "Polidoro":["ritratto","Vicolo"],"Polissena":["Ritratto","santa"],"Priamo":["san","santo","Sulis","Fumagalli"],"Scilla":["topografica","veduta","paesaggio"],
    "Telemaco":["stemma","ritratto"],"Teseo":["Spirito"],"Tolomeo":["San","Santi","Ritratto","beato"],"Urano":["Monte"],
    "Venere":["Giorgio","Castello","modella","tempio"],"Verità":["stemma","Pierantonio","ritratto"],"Vittorie":["reggitarga"],
    "Speranza":["ritratto","santa","chiesa","papa","san","santo","madonna"],"Scilla":["ritratto"],"Serapide":["tempio"],"Achille":["stemma","ritratto","duomo","san"],
    "Adone":["sant"],"Cibele":["tempio"],"Cirene":["simone","palazzo"],"Teseo":["tempio","ritratto"],"Titano":["san"],"Ulisse":["ritratto","Dini","cardinalizia"],"Zeus":["tempio"]

}


def validate_matches(row):
    subject = row["subject"]
    valid_matches = []

    for match in row["matched_term"]:

        # PRIMO CHECK: controlla se il termine è nelle exclusion_rules
        if match in exclusion_rules:
            exclusion_keywords = exclusion_rules[match]
            # se almeno una parola di esclusione è presente, scarta il termine
            if any(re.search(r'\b' + re.escape(k) + r'\b', subject, re.IGNORECASE) for k in exclusion_keywords):
                continue  
        
        # SECONDO CHECK: controlla context_rules 
        # se il termine non ha regole → tienilo
        if match not in context_rules:
            valid_matches.append(match)
            continue

        # controlla parole contestuali se il match è ambiguo 
        keywords = context_rules[match]

        if any(re.search(r'\b' + re.escape(k) + r'\b', subject, re.IGNORECASE) for k in keywords):
            valid_matches.append(match)

    return valid_matches


df_arco["matched_term"] = df_arco["subject"].str.findall(regex) #trova tutti i termini e restituisce la lista
df_arco["matched_term"] = df_arco.apply(validate_matches, axis=1) #fa i controlli definiti sopra 

# df che risulta
df_matches = df_arco[df_arco["matched_term"].str.len() > 0]

# %%
# Verifica i risultati
print(f"Totale beni Arco: {len(df_arco)}")
print(f"Beni con match mitologico: {len(df_matches)}")
# Out:
# Totale beni Arco: 522846
# Beni con match mitologico: 9686

# %%
#ulteriore iterazione NON case sensitive 
extra_check_terms = [
    "Aracne", "Argo", "Argonauti", "Arpia", "Arpie","Ascanio", "Callisto", "Centauro", "Cerva di Cerinea", "ciclope", "ciclopi", 
    "Chimera", "Cinghiale calidonio", "Cinghiale di Erimanto","Cupido", "Didone", "Elena", "Ippocampo",
    "Ippolito", "idra", "Minotauro", "musa", "muse", "putto", "putti", "Ratto di Europa","Sibilla samia", "Sibilla eritrea", "Sibilla tiburtina","Sirena", "Siringa", "Tritone", "satiro", "satiri"
]


extra_terms = [re.escape(t) for t in extra_check_terms]  #mette in sicurezza le parole per la regex 

extra_pattern = r'(?<![A-Za-zÀ-ÿ])(' + '|'.join(extra_terms) + r')(?![A-Za-zÀ-ÿ])'  
extra_regex = re.compile(extra_pattern, re.IGNORECASE)  #non case sensitive

#creo una copia del dataframe
df_matches = df_matches.copy()

# converte lista in set per confronto veloce
df_matches["matched_term_set"] = df_matches["matched_term"].apply(
    lambda x: set(x) if isinstance(x, list) else set()
)

#nuovo check
def find_new_matches(row):
    subject = row["subject"]
    already_found = row["matched_term_set"]

    all_hits = set(extra_regex.findall(subject))

    # rimuove quelli già trovati nel primo passaggio
    new_hits = all_hits - already_found

    return list(new_hits)


#applichiamo la funzione e creiamo una nuova colonna con gli extra_matched_terms
df_matches["extra_matched_terms"] = df_matches.apply(find_new_matches, axis=1)

#teniamo solo le righe utili
df_extra_hits = df_matches[df_matches["extra_matched_terms"].str.len() > 0].copy()

# %%
#normalizziamo i termini per poterli confrontare 
def normalize(s):
    return s.lower().strip() if isinstance(s, str) else ""

def merge_terms(row):
    base = row["matched_term"] if isinstance(row["matched_term"], list) else []
    extra = row["extra_matched_terms"] if isinstance(row["extra_matched_terms"], list) else []

    base_norm = {normalize(x): x for x in base}
    extra_norm = {normalize(x): x for x in extra}

    final = set()

    # 1. tengo gli extra che sono più specifici (es. europa --> ratto d'europa)
    for k, v in extra_norm.items():
        final.add(v)

    for b_key, b_val in base_norm.items():
        is_redundant = False

        for e_key in extra_norm:
            if b_key in e_key and b_key != e_key:
                is_redundant = True
                break

        if not is_redundant:
            final.add(b_val)  #tengo i termini base solo se non c'è una versione più specifica

    return list(final)

#applichiamo la funzione per avere i matched_term completi e più specifici
df_matches["final_terms"] = df_matches.apply(merge_terms, axis=1)

#df_matches[["subject", "final_terms"]].head()
df_checked = df_matches.sort_values(by="final_terms")[["item","label","subject", "final_terms"]]

# %%
print(len(df_checked))
# Out:
# 9686

# %%
#esportiamo i risultati in un file csv

df_checked.to_csv("arco_myth_matches.csv", index=False, encoding="utf-8")

# %%
# riconciliazione entities wikidata rappresentate in entities arco

df_wd_merged = df_wikidata.melt(id_vars=["entity"], value_vars=["label", "aliases"])[
    ["entity", "value"]
].dropna()
df_wd_merged["value"] = df_wd_merged["value"].str.strip().str.lower()

# Dictionary: {term: uri}
mapping_dict = dict(zip(df_wd_merged["value"], df_wd_merged["entity"]))
print("The mapping dictionary:", mapping_dict)

def map_strings_to_uris(string_list):
    if not isinstance(string_list, list):
        return None

    # Cerchiamo l'URI nel dizionario per ogni parola (rimuovendo spazi e minuscole)
    uris = []
    for s in string_list:
        clean_string = str(s).strip().lower()
        if clean_string in mapping_dict:
            uris.append(mapping_dict[clean_string])

    if not uris:
        return None
    elif len(uris) == 1:
        return uris[0]  
    else:
        return ", ".join(uris)  # concatenate in one line if there is more than one

    
    
df_arco_wd_entities = df_checked.copy()
print(df_arco_wd_entities.shape)
#print(df_arco_wd_entities["final_terms"].dtype)
df_arco_wd_entities["wd_entities"] = df_arco_wd_entities["final_terms"].apply(map_strings_to_uris) # l'input è a riga del df
print("The updated dataframe:\n", df_arco_wd_entities.head(5))
print("Entity column:\n", df_arco_wd_entities["wd_entities"])
# Out:
# The mapping dictionary: {'abarbarea': 'http://www.wikidata.org/entity/Q279782', 'acanto': 'http://www.wikidata.org/entity/Q9143205', 'acaste': 'http://www.wikidata.org/entity/Q9143220', 'accò': 'http://www.wikidata.org/entity/Q3604219', 'acefalo': 'http://www.wikidata.org/entity/Q417341', 'acheloo': 'http://www.wikidata.org/entity/Q391379', 'acheso': 'http://www.wikidata.org/entity/Q605797', 'achlys': 'http://www.wikidata.org/entity/Q340545', 'acmone': 'http://www.wikidata.org/entity/Q33191300', 'acrato': 'http://www.wikidata.org/entity/Q12647288', 'adefagia': 'http://www.wikidata.org/entity/Q356321', 'adikia': 'http://www.wikidata.org/entity/Q2824393', 'admete': 'http://www.wikidata.org/entity/Q17748154', 'adone': 'http://www.wikidata.org/entity/Q163920', 'adrastea': 'http://www.wikidata.org/entity/Q16737262', 'aergia': 'http://www.wikidata.org/entity/Q3844469', 'afaia': 'http://www.wikidata.org/entity/Q618401', 'afrodite': 'http://www.wikidata.org/entity/Q35500', 'afrodite pandemos': 'http://www.wikidata.org/entity/Q4779733', 'aganippe': 'http://www.wikidata.org/entity/Q390441', 'agastene': 'http://www.wikidata.org/entity/Q2723619', 'agathodaimon': 'http://www.wikidata.org/entity/Q391553', 'agave': 'http://www.wikidata.org/entity/Q15220128', 'agdistis': 'http://www.wikidata.org/entity/Q392120', 'aglaia': 'http://www.wikidata.org/entity/Q4439972', 'agrio': 'http://www.wikidata.org/entity/Q2827213', 'aidos': 'http://www.wikidata.org/entity/Q404076', 'aion': 'http://www.wikidata.org/entity/Q164846', 'alalà': 'http://www.wikidata.org/entity/Q391089', 'alastore': 'http://www.wikidata.org/entity/Q21548208', 'alce': 'http://www.wikidata.org/entity/Q21548229', 'alessiroe': 'http://www.wikidata.org/entity/Q3610598', 'aletheia': 'http://www.wikidata.org/entity/Q1317994', 'alfeo': 'http://www.wikidata.org/entity/Q911084', 'algea': 'http://www.wikidata.org/entity/Q10405146', 'alia': 'http://www.wikidata.org/entity/Q1571021', 'aliba': 'http://www.wikidata.org/entity/Q5974711', 'alpo': 'http://www.wikidata.org/entity/Q926123', 'amadriade': 'http://www.wikidata.org/entity/Q18450783', 'amaltea': 'http://www.wikidata.org/entity/Q107785', 'ammone': 'http://www.wikidata.org/entity/Q3575327', 'anaideia': 'http://www.wikidata.org/entity/Q4750926', 'ananke': 'http://www.wikidata.org/entity/Q332246', 'anauro': 'http://www.wikidata.org/entity/Q12648311', 'anax': 'http://www.wikidata.org/entity/Q2303713', 'anchiale': 'http://www.wikidata.org/entity/Q10856281', 'anchinoe': 'http://www.wikidata.org/entity/Q3615214', 'anchiroe': 'http://www.wikidata.org/entity/Q22965379', 'anfitrite': 'http://www.wikidata.org/entity/Q180222', 'angelia': 'http://www.wikidata.org/entity/Q4762641', 'anigro': 'http://www.wikidata.org/entity/Q12648474', 'anippe': 'http://www.wikidata.org/entity/Q10411954', 'anteros': 'http://www.wikidata.org/entity/Q572133', 'antracia': 'http://www.wikidata.org/entity/Q29686726', 'apollo': 'http://www.wikidata.org/entity/Q37340', 'ardesco': 'http://www.wikidata.org/entity/Q8203830', 'ares': 'http://www.wikidata.org/entity/Q40901', 'aretè': 'http://www.wikidata.org/entity/Q265823', 'argiope': 'http://www.wikidata.org/entity/Q3622437', 'aristeo': 'http://www.wikidata.org/entity/Q2861418', 'armonia': 'http://www.wikidata.org/entity/Q978079', 'arpocrate': 'http://www.wikidata.org/entity/Q787492', 'artemide': 'http://www.wikidata.org/entity/Q39503', 'asclepio': 'http://www.wikidata.org/entity/Q83223', 'asopo': 'http://www.wikidata.org/entity/Q622781', 'aspide': 'http://www.wikidata.org/entity/Q737614', 'assio': 'http://www.wikidata.org/entity/Q4830640', 'assioche': 'http://www.wikidata.org/entity/Q931321', 'ashtoreth': 'http://www.wikidata.org/entity/Q130274', 'asterione': 'http://www.wikidata.org/entity/Q24055357', 'asterodia': 'http://www.wikidata.org/entity/Q2868652', 'asterope': 'http://www.wikidata.org/entity/Q748963', 'astioche': 'http://www.wikidata.org/entity/Q284487', 'astrea': 'http://www.wikidata.org/entity/Q742680', 'astreo': 'http:/ ...
# (9686, 4)
# The updated dataframe:
#                                                        item  \
# 1578996  https://w3id.org/arco/resource/HistoricOrArtis...
# 607290   https://w3id.org/arco/resource/HistoricOrArtis...
# 1110588  https://w3id.org/arco/resource/HistoricOrArtis...
# 1116076  https://w3id.org/arco/resource/HistoricOrArtis...
# 1118452  https://w3id.org/arco/resource/HistoricOrArtis...
#
#                                                      label  \
# 1578996  Abbondanza; Carità; Sapienza; Temperanza (stat...
# 607290   Abbondanza (dipinto) by Falcone Aniello (sec. ...
# 1110588  Abbondanza (placchetta) - ambito Italia centra...
# 1116076  ..................., Abbondanza, Fede e angiol...
# 1118452  Abbondanza (statuetta) - ambito di Augusta (me...
#
#                                             subject   final_terms  \
# 1578996    Abbondanza; Carità; Sapienza; Temperanza  [Abbondanza]
# 607290                                   Abbondanza  [Abbondanza]
# 1110588                                  Abbondanza  [Abbondanza]
# 1116076  Abbondanza, Fede e angioletti con la croce  [Abbondanza]
# 1118452                                  Abbondanza  [Abbondanza]
#
#                                     wd_entities
# 1578996  http://www.wikidata.org/entity/Q336003
# 607290   http://www.wikidata.org/entity/Q336003
# 1110588  http://www.wikidata.org/entity/Q336003
# 1116076  http://www.wikidata.org/entity/Q336003
# 1118452  http://www.wikidata.org/entity/Q336003
# Entity column:
#  1578996               http://www.wikidata.org/entity/Q336003
# 607290                http://www.wikidata.org/entity/Q336003
# 1110588               http://www.wikidata.org/entity/Q336003
# 1116076               http://www.wikidata.org/entity/Q336003
# 1118452               http://www.wikidata.org/entity/Q336003
#                                  ...
# 421360     http://www.wikidata.org/entity/Q846129, http:/...
# 311334     http://www.wikidata.org/entity/Q846129, http:/...
# 678612     http://www.wikidata.org/entity/Q846129, http:/...
# 1935380    http://www.wikidata.org/entity/Q148030, http:/...
# 2017320    http://www.wikidata.org/entity/Q148030, http:/...
# Name: wd_entities, Length: 9686, dtype: object

# %%
# dump csv integrato con uris wikidata
df_arco_wd_entities.to_csv("arco_wd_entities.csv", index=False, encoding="utf-8")

# %%
arco_endpoint = "https://dati.cultura.gov.it/sparql"
sparql_arco = SPARQLWrapper(arco_endpoint)
sparql_arco.setReturnFormat(JSON)

df_base = pd.read_csv("arco_myth_matches.csv", encoding="utf-8")
items = df_base["item"].dropna().unique().tolist() #estraggo la lista di item unici per poi fare ulteriori query su Wikidata

# %%
# funzione per eseguire query in batch su SPARQL

def run_batched_query(items_list, query_template, batch_size=100):

    all_dfs = []

    for i in range(0, len(items_list), batch_size):

        batch = items_list[i:i + batch_size]
        formatted_items = " ".join(f"<{uri}>" for uri in batch) 

        query = query_template.replace("{ITEMS}", formatted_items)

        sparql_arco.setQuery(query)

        try:
            results = sparql_arco.query().convert()

            rows = []
            for r in results["results"]["bindings"]:
                rows.append({k: v["value"] for k, v in r.items()})

            if rows:
                all_dfs.append(pd.DataFrame(rows))

        except Exception as e:
            print(f"Errore batch {i}: {e}")

    if all_dfs:
        return pd.concat(all_dfs, ignore_index=True)

    return pd.DataFrame()

# %%
#QUERY 1: identifier, creators, types

query_ict= """ 
        PREFIX arco: <https://w3id.org/arco/ontology/arco/>
        PREFIX a-dd: <https://w3id.org/arco/ontology/denotative-description/>
        PREFIX a-loc: <https://w3id.org/arco/ontology/location/>
        PREFIX dc: <http://purl.org/dc/elements/1.1/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        
        SELECT ?item ?identifier      
            (GROUP_CONCAT(DISTINCT ?creator; separator=", ") AS ?creators) 
            (SAMPLE (?creatorL) AS ?creatorLabel) 

            (GROUP_CONCAT(DISTINCT ?type; separator=", ") AS ?types) 
            (SAMPLE (?typeL) AS ?typeLabel) 

            (GROUP_CONCAT(DISTINCT ?instituteOrSite; separator=", ") AS ?institutesOrSites)
            (SAMPLE (?instituteOrSiteL) AS ?institutesOrSiteLabel) 
            
            (GROUP_CONCAT(DISTINCT ?place; separator=", ") AS ?coverage)
            (SAMPLE (?placeL) AS ?coverageLabel)
        
        WHERE {
            VALUES ?item {{ITEMS}} .
            # ?item arco:uniqueIdentifier ?identifier .
 
            OPTIONAL {
                # ?item dc:creator ?creator . 
                OPTIONAL {?creator rdfs:label ?creatorL .}
                }

            OPTIONAL {
                # ?item a-dd:hasCulturalPropertyType ?type . 
                OPTIONAL {
                    # ?type rdfs:label ?typeL .
                    FILTER(LANG(?typeL) = "it")
                    FILTER (!CONTAINS(STR(?typeL), "Tipo del bene:"))       
                }
            } 

            OPTIONAL {
                # ?item a-loc:hasCulturalInstituteOrSite ?instituteOrSite . 
                OPTIONAL {?instituteOrSite rdfs:label ?instituteOrSiteL .}
                }

            OPTIONAL {
                # ?item dc:coverage ?place .
                OPTIONAL {?place rdfs:label ?placeL .}
            } 
        }    
        
 
        GROUP BY ?item ?identifier
        """

# %%
#Q2 creation - date range 

query_date = """ 
        PREFIX arco: <https://w3id.org/arco/ontology/arco/>
        PREFIX a-cd: <https://w3id.org/arco/ontology/context-description/>

        SELECT ?item 
            (SAMPLE(STR(?event)) AS ?event)
            (SAMPLE(STR(?startDate)) AS ?start) 
            (SAMPLE(STR(?endDate)) AS ?end)
        WHERE {
            VALUES ?item 
                {{ITEMS}}
    
        OPTIONAL {
            # ?item a-cd:hasDating ?dating .
            # ?dating a-cd:hasDatingEvent ?event .
            # ?event a-cd:specificTime ?time .
            # ?time arco:startTime ?startDate ;
              arco:endTime ?endDate .
        
            # Filtro per assicurarci di prendere solo la creazione
            FILTER(REGEX(STR(?event), "creation", "i"))
        }        
    }
    GROUP BY ?item 
        """

# %%
#QUERY 3 - geometries and locations 
query_location = """ 
        PREFIX a-loc: <https://w3id.org/arco/ontology/location/>
        PREFIX clvapit: <https://w3id.org/italia/onto/CLV/>
        SELECT ?item
            (SAMPLE(STR(?geometry)) AS ?geometry) 
            (SAMPLE(STR(?lat)) AS ?lat)
            (SAMPLE(STR(?long)) AS ?long)
        WHERE {
            VALUES ?item {{ITEMS}} .
            # OPTIONAL per coordinate geografiche
            OPTIONAL {
                # ?item clvapit:hasGeometry ?geometry .
                # ?geometry a-loc:hasCoordinates ?coordinates .
                # ?coordinates a-loc:lat ?lat ;
                            a-loc:long ?long .
            }        
        }
        GROUP BY ?item 
        """

# %%
#QUERY 4 - images 
query_img = """ 
        PREFIX foaf: <http://xmlns.com/foaf/0.1/>
 
        SELECT ?item (SAMPLE(?image) AS ?sampleImage) #  solo una tra quelle disponibili
        WHERE {
            VALUES ?item {{ITEMS}} .
            OPTIONAL {?item foaf:depiction ?image . }        
        }
	GROUP BY ?item
        """

# %%
#eseguo le query 
df_ict = run_batched_query(items, query_ict, batch_size=50)

# %%
df_date = run_batched_query(items, query_date,batch_size=50)

# %%
df_location = run_batched_query(items, query_location, batch_size=50)

# %%
df_img = run_batched_query(items, query_img, batch_size=50)

# %%
#creo un df unico 
df_enriched = df_base \
    .merge(df_ict, on="item", how="left") \
    .merge(df_date, on="item", how="left") \
    .merge(df_location, on="item", how="left") \
    .merge(df_img, on="item", how="left")

# %%
df_enriched.to_csv("arco_myth_enriched.csv", index=False)
print(len(df_enriched))
# Out:
# 9686

# %%
#VISUALIZZIAMO IL DF ENRICHED 

df =pd.read_csv("arco_myth_enriched.csv")
df.head(1)
print(f"The enriched df has {len(df)} rows")
# Out:
# The enriched df has 9686 rows

# %%
#VISUALIZZIAMO SOLO LE LABEL DEL DF  --------------- questo lo possiamo togliere?

df = pd.read_csv("arco_myth_enriched.csv")

colonne_selezionate = [
    "item",
    "label",
    "subject",
    "final_terms",
    "typeLabel",
    "creatorLabel",
    "institutesOrSiteLabel",
    "coverage",
    "start",
    "end"
]

df_label = df[colonne_selezionate].copy()
df_label.head(5)
# Out:
#                                                 item  \
# 0  https://w3id.org/arco/resource/HistoricOrArtis...
# 1  https://w3id.org/arco/resource/HistoricOrArtis...
# 2  https://w3id.org/arco/resource/HistoricOrArtis...
# 3  https://w3id.org/arco/resource/HistoricOrArtis...
# 4  https://w3id.org/arco/resource/HistoricOrArtis...
#
#                                                label  \
# 0  Abbondanza; Carità; Sapienza; Temperanza (stat...
# 1  Abbondanza (dipinto) by Falcone Aniello (sec. ...
# 2  Abbondanza (placchetta) - ambito Italia centra...
# 3  ..................., Abbondanza, Fede e angiol...
# 4  Abbondanza (statuetta) - ambito di Augusta (me...
#
#                                       subject     final_terms  \
# 0    Abbondanza; Carità; Sapienza; Temperanza  ['Abbondanza']
# 1                                  Abbondanza  ['Abbondanza']
# 2                                  Abbondanza  ['Abbondanza']
# 3  Abbondanza, Fede e angioletti con la croce  ['Abbondanza']
# 4                                  Abbondanza  ['Abbondanza']
#
#           typeLabel                                creatorLabel  \
# 0            statua                                         NaN
# 1           dipinto                Falcone Aniello (1607/ 1656)
# 2        placchetta                                         NaN
# 3  gruppo scultoreo  Baratta Giovanni Maria - notizie 1658-1666
# 4         statuetta                                         NaN
#
#                     institutesOrSiteLabel            coverage    start  \
# 0                                     NaN  Cortemaggiore (PC)  ca 1725
# 1                                     NaN         Napoli (NA)     1641
# 2                            Museo Civico          Rieti (RI)     1800
# 3                                     NaN           Roma (RM)  ca 1663
# 4  Museo Nazionale del Palazzo di Venezia           Roma (RM)     1540
#
#        end
# 0  ca 1749
# 1     1641
# 2     1899
# 3  ca 1663
# 4     1560

# %%
# df arco enriched con uris wikidata

df_arco_wd =  pd.merge(df_enriched, df_arco_wd_entities, on="item", how="left")
#print(f"Entities df:\n {df_arco_wd['wd_entities']}")
df_arco_wd.head(5)
#print(f"The final df has {len(df_arco_wd)} rows")


# find and combine duplicate _x and _y columns
for col in df_enriched.columns:
    if col != "item" and f"{col}_x" in df_arco_wd.columns:
        # Combine the two columns (prefers _x, fills NaNs with _y)
        df_arco_wd[col] = df_arco_wd[f"{col}_x"].combine_first(df_arco_wd[f"{col}_y"])
        
        # Drop the duplicate columns
        df_arco_wd.drop(columns=[f"{col}_x", f"{col}_y"], inplace=True)

df_arco_wd.head(5)
#print(f"The final df has {len(df_arco_wd)} rows")
# Out:
#                                                 item  identifier  \
# 0  https://w3id.org/arco/resource/HistoricOrArtis...  0800156305
# 1  https://w3id.org/arco/resource/HistoricOrArtis...  1500376649
# 2  https://w3id.org/arco/resource/HistoricOrArtis...  1200010115
# 3  https://w3id.org/arco/resource/HistoricOrArtis...  1200262506
# 4  https://w3id.org/arco/resource/HistoricOrArtis...  1200865101
#
#                                             creators  \
# 0
# 1  https://w3id.org/arco/resource/Agent/aa9533f2a...
# 2
# 3  https://w3id.org/arco/resource/Agent/933d26813...
# 4
#
#                                                types         typeLabel  \
# 0  https://w3id.org/arco/resource/CulturalPropert...            statua
# 1  https://w3id.org/arco/resource/CulturalPropert...           dipinto
# 2  https://w3id.org/arco/resource/CulturalPropert...        placchetta
# 3  https://w3id.org/arco/resource/CulturalPropert...  gruppo scultoreo
# 4  https://w3id.org/arco/resource/CulturalPropert...         statuetta
#
#                                    institutesOrSites  \
# 0
# 1
# 2  https://w3id.org/arco/resource/CulturalInstitu...
# 3
# 4  https://w3id.org/arco/resource/CulturalInstitu...
#
#                     institutesOrSiteLabel            coverage  \
# 0                                     NaN  Cortemaggiore (PC)
# 1                                     NaN         Napoli (NA)
# 2                            Museo Civico          Rieti (RI)
# 3                                     NaN           Roma (RM)
# 4  Museo Nazionale del Palazzo di Venezia           Roma (RM)
#
#                                  creatorLabel  \
# 0                                         NaN
# 1                Falcone Aniello (1607/ 1656)
# 2                                         NaN
# 3  Baratta Giovanni Maria - notizie 1658-1666
# 4                                         NaN
#
#                                                event    start      end  \
# 0  https://w3id.org/arco/resource/Event/080015630...  ca 1725  ca 1749
# 1  https://w3id.org/arco/resource/Event/150037664...     1641     1641
# 2  https://w3id.org/arco/resource/Event/120001011...     1800     1899
# 3  https://w3id.org/arco/resource/Event/120026250...  ca 1663  ca 1663
# 4  https://w3id.org/arco/resource/Event/120086510...     1540     1560
#
#                                             geometry        lat       long  \
# 0                                                NaN        NaN        NaN
# 1  https://w3id.org/arco/resource/Geometry/150037...  40.850863  14.256959
# 2  https://w3id.org/arco/resource/Geometry/120001...  42.405306  12.851576
# 3  https://w3id.org/arco/resource/Geometry/120026...  41.904832  12.490884
# 4  https://w3id.org/arco/resource/Geometry/120086...  41.896597  12.481470
#
#                                          sampleImage  \
# 0  https://sigecweb.beniculturali.it/images/fulls...
# 1  https://sigecweb.beniculturali.it/images/fulls...
# 2  http://www.sigecweb.beniculturali.it/images/fu...
# 3  https://www.sigecweb.beniculturali.it/images/f...
# 4  https://www.sigecweb.beniculturali.it/images/f...
#
#                               wd_entities  \
# 0  http://www.wikidata.org/entity/Q336003
# 1  http://www.wikidata.org/entity/Q336003
# 2  http://www.wikidata.org/entity/Q336003
# 3  http://www.wikidata.org/entity/Q336003
# 4  http://www.wikidata.org/entity/Q336003
#
#                                                label  \
# 0  Abbondanza; Carità; Sapienza; Temperanza (stat...
# 1  Abbondanza (dipinto) by Falcone Aniello (sec. ...
# 2  Abbondanza (placchetta) - ambito Italia centra...
# 3  ..................., Abbondanza, Fede e angiol...
# 4  Abbondanza (statuetta) - ambito di Augusta (me...
#
#                                       subject     final_terms
# 0    Abbondanza; Carità; Sapienza; Temperanza  ['Abbondanza']
# 1                                  Abbondanza  ['Abbondanza']
# 2                                  Abbondanza  ['Abbondanza']
# 3  Abbondanza, Fede e angioletti con la croce  ['Abbondanza']
# 4                                  Abbondanza  ['Abbondanza']

# %%
# extend df with normalized dates
def clean_dates(string_date):
    date_to_lower = str(string_date).lower().strip()
    match = date_to_lower
    
    if not match:
        return pd.Series({
            'norm_date': None
        })
    
    def process(block):
        block = block.strip()
        
        # Colonna normalizzata (gestione dei vari formati)
        norm = None
        
        # formato date (yyyy/mm/dd)
        # trasformazione in in yyyy-mm-dd
        date_format = re.search(r'(\d{4})[/-](\d{2})[/-](\d{2})', block)
        
        # intervallo anno-anno (es. 1881-1882)
        interval = re.search(r'(\d{4})-(\d{4})', block)

        # anno
        year_match = re.search(r'\d{4}', block)

        if date_format:
            # Estrarre gruppi e sostituire / con -
            norm = f"{date_format.group(1)}-{date_format.group(2)}-{date_format.group(3)}"
        
        elif interval:
            # estrarre margine estremo dell'intervallo
            norm = f"{interval.group(2)}"

        elif year_match:
            year_val = int(year_match.group(0))
            # aggiungere un anno per 'post'
            if 'post' in block:
                norm = year_val + 1
            # sottrarre un anno per 'ante'
            elif 'ante' in block:
                norm = year_val - 1
            else:
                norm = year_val
        
        return norm

    # restituire data normalizzata
    norm_date = process(match)
    
    return pd.Series({
        'norm_date': norm_date,
    })

# %%
# apply function
# column for normalized start date
df_arco_wd[['start_norm']] = df_arco_wd['start'].apply(clean_dates)
# column for normalized end date
df_arco_wd[['end_norm']] = df_arco_wd['end'].apply(clean_dates)

df_arco_wd[['start', 'start_norm', 'end', 'end_norm']].head(20)
# Out:
#         start start_norm        end end_norm
# 0     ca 1725       1725    ca 1749     1749
# 1        1641       1641       1641     1641
# 2        1800       1800       1899     1899
# 3     ca 1663       1663    ca 1663     1663
# 4        1540       1540       1560     1560
# 5        1759       1759       1760     1760
# 6        1545       1545       1547     1547
# 7        1700       1700       1799     1799
# 8        1800       1800       1899     1899
# 9     ca 1675       1675    ca 1699     1699
# 10       1600       1600       1699     1699
# 11   (?) 1700       1700   (?) 1786     1786
# 12   (?) 1519       1519   (?) 1539     1539
# 13    ca 1600       1600    ca 1699     1699
# 14  post 1600       1601  ante 1649     1648
# 15   (?) 1500       1500       1699     1699
# 16       1550       1550       1599     1599
# 17   (?) 1500       1500       1699     1699
# 18       1615       1615       1615     1615
# 19    ca 1730       1730    ca 1732     1732

# %%
# --------------- codice per estrazione properties wikidata -------------- #

# pulizia matched terms
""" def clean_terms(term):
    cleaned_term = term.strip("[").strip("]")
    return cleaned_term

# sto prendendo dal df completo di arco_myth_enriched
terms_to_match = df["final_terms"].apply(clean_terms)
print("Terms to match\n", terms_to_match.head)
# set dei termini matchati in arco
set_of_matched_terms = set()

for idx, term_list in terms_to_match.items():
    #print("Processing item", idx)
    if isinstance(term_list, str):
        for term in term_list.split(","):
            cleaned_element = term.strip().strip("'").strip()
            # per evitare che stesso nome con maiuscola/minuscola sporchi il set
            cleaned_cap = cleaned_element.capitalize() if cleaned_element.islower() else cleaned_element
            set_of_matched_terms.add(cleaned_cap)

print("the set of terms:\n", set_of_matched_terms)
print("The set counts", len(set_of_matched_terms), "terms") """
# Out:
# ' def clean_terms(term):\n    cleaned_term = term.strip("[").strip("]")\n    return cleaned_term\n\n# sto prendendo dal df completo di arco_myth_enriched\nterms_to_match = df["final_terms"].apply(clean_terms)\nprint("Terms to match\n", terms_to_match.head)\n# set dei termini matchati in arco\nset_of_matched_terms = set()\n\nfor idx, term_list in terms_to_match.items():\n    #print("Processing item", idx)\n    if isinstance(term_list, str):\n        for term in term_list.split(","):\n            cleaned_element = term.strip().strip("\'").strip()\n            # per evitare che stesso nome con maiuscola/minuscola sporchi il set\n            cleaned_cap = cleaned_element.capitalize() if cleaned_element.islower() else cleaned_element\n            set_of_matched_terms.add(cleaned_cap)\n\nprint("the set of terms:\n", set_of_matched_terms)\nprint("The set counts", len(set_of_matched_terms), "terms") '

# %%
# estrazione entità wikidata (filtro su label e alias)
""" wd_dataset = pd.read_csv("wd_dataset.csv", encoding="utf-8")
#print(wd_dataset.head)

wd_matched_entities = set()

for term in set_of_matched_terms:
    #print("I am looking for", term)
    check = (wd_dataset['label'] == term) | (wd_dataset['aliases'] == term)
    
    entities_to_extract = wd_dataset.loc[check, 'entity'].tolist()
    print("The match for", term, "is", entities_to_extract)
    
    # aggiungi entity al set
    for entity in entities_to_extract:
        if entity:
            wd_matched_entities.add(entity)

print("The set of extracted entities:\n", wd_matched_entities)
print("The set of extracted entities counts:", len(wd_matched_entities), "uris")

wd_matched_entities_list = list(wd_matched_entities) """

# ne abbiamo di più perché guarda anche aliases (?)
# Out:
# ' wd_dataset = pd.read_csv("wd_dataset.csv", encoding="utf-8")\n#print(wd_dataset.head)\n\nwd_matched_entities = set()\n\nfor term in set_of_matched_terms:\n    #print("I am looking for", term)\n    check = (wd_dataset[\'label\'] == term) | (wd_dataset[\'aliases\'] == term)\n    \n    entities_to_extract = wd_dataset.loc[check, \'entity\'].tolist()\n    print("The match for", term, "is", entities_to_extract)\n    \n    # aggiungi entity al set\n    for entity in entities_to_extract:\n        if entity:\n            wd_matched_entities.add(entity)\n\nprint("The set of extracted entities:\n", wd_matched_entities)\nprint("The set of extracted entities counts:", len(wd_matched_entities), "uris")\n\nwd_matched_entities_list = list(wd_matched_entities) '

# %%
# set wikidata endpoint
#wd_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql" # sui tutorial c'è questo
# set endpoint
#sparql_wd = SPARQLWrapper(wd_endpoint)

# %%
# function for wikidata queries
""" def extract_batch_properties(entities_list, query_prop, batch_size=3):
    all_properties = []

    for i in range(0, len(entities_list), batch_size):
        batch = entities_list[i:i + batch_size]
        formatted_items = " ".join(f"<{uri}>" for uri in batch) 

        query = query_prop.replace("{ENTITIES}", formatted_items)

        sparql_wd.setQuery(query_prop)
        sparql_wd.setReturnFormat(JSON)

        try:
            results = sparql_wd.query().convert()

            for r in results["results"]["bindings"]:
                # Controlliamo i dati reali restituiti da Wikidata
                property_uri = r["property"]["value"] if "property" in r else "N/A"

                # Il servizio aggiunge SEMPRE "Label" al nome della variabile principale
                if (
                    "propertyLabel" in r
                    and r["propertyLabel"]["value"] != property_uri
                ):
                    label = r["propertyLabel"]["value"]
                else:
                    # Se il label service fallisce, estraiamo l'ID finale (es. P31) come fallback
                    label = property_uri.split("/")[-1]

                all_properties.append({"property": property_uri, "label": label})

        except Exception as e:
            print(f"Errore: {e}")
            return []

        return all_properties """
# Out:
# ' def extract_batch_properties(entities_list, query_prop, batch_size=3):\n    all_properties = []\n\n    for i in range(0, len(entities_list), batch_size):\n        batch = entities_list[i:i + batch_size]\n        formatted_items = " ".join(f"<{uri}>" for uri in batch) \n\n        query = query_prop.replace("{ENTITIES}", formatted_items)\n\n        sparql_wd.setQuery(query_prop)\n        sparql_wd.setReturnFormat(JSON)\n\n        try:\n            results = sparql_wd.query().convert()\n\n            for r in results["results"]["bindings"]:\n                # Controlliamo i dati reali restituiti da Wikidata\n                property_uri = r["property"]["value"] if "property" in r else "N/A"\n\n                # Il servizio aggiunge SEMPRE "Label" al nome della variabile principale\n                if (\n                    "propertyLabel" in r\n                    and r["propertyLabel"]["value"] != property_uri\n                ):\n                    label = r["propertyLabel"]["value"]\n                else:\n                    # Se il label service fallisce, estraiamo l\'ID finale (es. P31) come fallback\n                    label = property_uri.split("/")[-1]\n\n                all_properties.append({"property": property_uri, "label": label})\n\n        except Exception as e:\n            print(f"Errore: {e}")\n            return []\n\n        return all_properties '

# %%
# query estrazione proprietà wd a partire dal set di entities estratte
query_wd_properties = """ 
        SELECT DISTINCT ?property ?propertyLabel
        WHERE {
            # Prendiamo la relazione (wdt:...) e l'oggetto
            wd:Q11688446 ?propertyUri ?object .
            
            # Isoliamo solo le proprietà dirette
            FILTER(STRSTARTS(STR(?propertyUri), "http://www.wikidata.org/prop/direct/"))
            
            # Trasformiamo l'URI della relazione nell'URI dell'entità Proprietà (wd:P...)
            # Usiamo ?property come nome standard, così il SERVICE sa esattamente cosa cercare
            BIND(URI(REPLACE(STR(?propertyUri), "http://www.wikidata.org/prop/direct/", "http://www.wikidata.org/entity/")) AS ?property)
            
            # Il Label Service intercetta ?property e genera automaticamente ?propertyLabel
            SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
        }
        ORDER BY ?propertyLabel
        """

# %%
# run query
#wd_properties = extract_batch_properties(wd_matched_entities_list, query_wd_properties, batch_size=3)

# %%
""" def extract_properties(query_prop):
    all_properties = []

    sparql_wd.setQuery(query_prop)
    sparql_wd.setReturnFormat(JSON)

    try:
        results = sparql_wd.query().convert()

        for r in results["results"]["bindings"]:
            # Controlliamo i dati reali restituiti da Wikidata
            property_uri = r["property"]["value"] if "property" in r else "N/A"

            # Il servizio aggiunge SEMPRE "Label" al nome della variabile principale
            if (
                "propertyLabel" in r
                and r["propertyLabel"]["value"] != property_uri
            ):
                label = r["propertyLabel"]["value"]
            else:
                # Se il label service fallisce, estraiamo l'ID finale (es. P31) come fallback
                label = property_uri.split("/")[-1]

            if "ID" not in label:
                all_properties.append({"property": property_uri, "label": label}) # se label contiene "ID" non inserire nè property nè label

    except Exception as e:
        print(f"Errore: {e}")
        return []

    return all_properties

wd_properties = extract_properties(query_wd_properties)
print("Wikidata properties for one entity:", wd_properties) """
# Out:
# ' def extract_properties(query_prop):\n    all_properties = []\n\n    sparql_wd.setQuery(query_prop)\n    sparql_wd.setReturnFormat(JSON)\n\n    try:\n        results = sparql_wd.query().convert()\n\n        for r in results["results"]["bindings"]:\n            # Controlliamo i dati reali restituiti da Wikidata\n            property_uri = r["property"]["value"] if "property" in r else "N/A"\n\n            # Il servizio aggiunge SEMPRE "Label" al nome della variabile principale\n            if (\n                "propertyLabel" in r\n                and r["propertyLabel"]["value"] != property_uri\n            ):\n                label = r["propertyLabel"]["value"]\n            else:\n                # Se il label service fallisce, estraiamo l\'ID finale (es. P31) come fallback\n                label = property_uri.split("/")[-1]\n\n            if "ID" not in label:\n                all_properties.append({"property": property_uri, "label": label}) # se label contiene "ID" non inserire nè property nè label\n\n    except Exception as e:\n        print(f"Errore: {e}")\n        return []\n\n    return all_properties\n\nwd_properties = extract_properties(query_wd_properties)\nprint("Wikidata properties for one entity:", wd_properties) '
